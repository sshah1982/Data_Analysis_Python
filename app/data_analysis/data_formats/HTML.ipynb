# %%
# %run "..\\..\\config\\AppSettings.py"

import pandas as pd
#from app.config.AppSettings import AppSettings

# %%
settings = AppSettings()

url_list = []
url_list.append(settings._common_account)
url_list.append(settings._repo_name)
url_list.append(settings._branch_name)
url_list.append(settings._app_root)
url_list.append(settings._data_analysis_folder)
url_list.append(settings._raw_files_path)
url_list.append(settings._html_path)

html_url = settings._raw_data_url + "/".join(url_list)

df_html = pd.read_html(html_url)

# %%
df_html[0].head()
# Out:
#    Unnamed: 0  S_NO  PO_NUM  ORDER_DATE  \
# 0           0     1   99503  1999-10-20
# 1           1     2   99503  1999-10-20
# 2           2     3   99505  1999-10-22
# 3           3     4   99504  1999-10-22
# 4           4     5   99504  1999-10-22
#
#                                DELIVERY_NOTES    SHIPPING_NAME  \
# 0  Please leave packages in shed by driveway.      Ellen Adams
# 1  Please leave packages in shed by driveway.      Ellen Adams
# 2           Please notify me before shipping.  Cristian Osorio
# 3                                         NaN   Jessica Arnold
# 4                                         NaN   Jessica Arnold
#
#     SHIPPING_STREET SHIPPING_CITY SHIPPING_STATE  SHIPPING_ZIP  ...  \
# 0  123 Maple Street   Mill Valley             CA         10999  ...
# 1  123 Maple Street   Mill Valley             CA         10999  ...
# 2   456 Main Street       Buffalo             NY         98112  ...
# 3  4055 Madison Ave       Seattle             WA         98112  ...
# 4  4055 Madison Ave       Seattle             WA         98112  ...
#
#   BILLING_CITY BILLING_STATE BILLING_ZIP BILLING_COUNTRY ITEM_PART_NUMBER  \
# 0     Old Town            PA       95819             USA           872-AA
# 1     Old Town            PA       95819             USA           926-AA
# 2      Buffalo            NY       98112             USA           456-NM
# 3      Buffalo            NY       98112             USA           898-AZ
# 4      Buffalo            NY       98112             USA           898-AM
#
#            ITEM_NAME ITEM_QTY ITEM_PRICE ITEM_SHIP_DATE  \
# 0          Lawnmower        1     148.95            NaN
# 1       Baby Monitor        2      39.98     1999-05-21
# 2       Power Supply        1      45.99            NaN
# 3  Computer Keyboard        1      29.99            NaN
# 4     Wireless Mouse        1      14.99            NaN
#
#                ITEM_COMMENT
# 0  Confirm this is electric
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 23 columns]
